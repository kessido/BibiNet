# %%
import keras
from keras.models import Model, Sequential
from keras.layers import Input,Dense,LSTM,Dropout,LeakyReLU,Activation
from keras.layers import TimeDistributed,Flatten,Conv2D,Reshape,concatenate,Lambda
from keras.callbacks import ModelCheckpoint,TensorBoard
import keras.backend as K
import numpy as np
from tqdm import tqdm
import pickle as pkl
from random import sample
from time import time
import os
import pickle
import gc
import matplotlib.pyplot as plt
import sklearn
from keras.utils.vis_utils import plot_model
import itertools
from joblib import delayed, Parallel
from IPython.display import Image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #  Parameters

# %%
FACE_FEATURES_DIR = '../audio_target/1_face_features_min_max_scaled/'
AUDIO_FEATURES_DIR = '../audio_features/audio_features/'

# %%
time_delay = 50
look_back = 100

audio_frames_per_seconds = 200
video_frames_per_seconds = 20

tbCallback = TensorBoard(log_dir="logs/{}".format(time()))
# TensorBoard(log_dir='./Graph', histogram_freq=0, batch_size=n_batch, write_graph=True, write_images=True)

# %% [markdown]
# # Load data

# %%
face_features_files = os.listdir(FACE_FEATURES_DIR)
audio_features_files = os.listdir(AUDIO_FEATURES_DIR)

# %%
features_files = sorted(list(set(face_features_files).intersection(set(audio_features_files))))
features_files = [features_file for features_file in features_files if 'pickle' in features_file]
features_files.sort()
len(features_files)
# Out:
# 161

# %%
def _load_single(fn, subsample_one_every_n):
    X, X_extra, y = [], [], []
    with open(os.path.join(AUDIO_FEATURES_DIR,fn), 'rb') as f:
        audio = pickle.load(f)
    with open(os.path.join(FACE_FEATURES_DIR,fn), 'rb') as f:
        video = pickle.load(f) # face features

    for i_start in range(0,len(audio), subsample_one_every_n):
        i_end = i_start + look_back

        if i_end > len(audio):
            continue

        i_video = int(((i_start + look_back - time_delay) / audio_frames_per_seconds) * video_frames_per_seconds)

        if i_video < 0 or i_video >= len(video):
            continue

        a = audio[i_start:i_end]
        v = video[i_video]
        if np.any(v.std(axis=0)==0):
            continue
        X.append(a)
        X_extra.append(v[:48].reshape((48*2)))
        y.append(v[48:].reshape((20*2)))
    gc.collect()
    del video, audio
    gc.collect()
    return X, X_extra, y

# %%
def load_multiple(fns, subsample_one_every_n):
    def _concatenate(iterables_arr):
        return list(itertools.chain(*iterables_arr))
    res = []
    
    with tqdm(fns) as tqdm_fns:
        with Parallel(n_jobs=5) as par:
            res = par(delayed(_load_single)(fn, subsample_one_every_n) for fn in tqdm_fns)
    
    X, X_extra, y = [], [], []
    
    for X1, X_extra1, Y1 in res:
        X.append(X1)
        X_extra.append(X_extra1)
        y.append(Y1)
    
    gc.collect()
    X = np.array(_concatenate(X), dtype=np.float64)
    X_extra = np.array(_concatenate(X_extra), dtype=np.float64)
    y = np.array(_concatenate(y), dtype=np.float64)
    gc.collect()
    return X, X_extra, y

# %%
trainX, trainX_extra, trainy = load_multiple(features_files[:140], 30)
# Out:
# 100%|██████████| 140/140 [00:11<00:00, 12.77it/s]

# %%
validX, validX_extra, validy = load_multiple(features_files[140:], 200)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 966.63it/s]

# %%
testX, testX_extra, testy = load_multiple(features_files[140:141], 20)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 257.54it/s]

# %%
def print_shapes(X, X_extra, y, name):
    print(f'{name}X.shape\t\t',X.shape)
    print(f'{name}X_extra.shape\t',X_extra.shape)
    print(f'{name}y.shape\t\t',y.shape)
print_shapes(trainX, trainX_extra, trainy,'train')
print_shapes(validX, validX_extra, validy,'valid')
print_shapes(testX, testX_extra, testy,'test')
# Out:
# trainX.shape		 (134515, 100, 39)
# trainX_extra.shape	 (134515, 96)
# trainy.shape		 (134515, 40)
# validX.shape		 (2301, 100, 39)
# validX_extra.shape	 (2301, 96)
# validy.shape		 (2301, 40)
# testX.shape		 (1195, 100, 39)
# testX_extra.shape	 (1195, 96)
# testy.shape		 (1195, 40)

# %% [markdown]
# # Normalize Data

# %%
def mean_to_0(y):
    y[:,::2] -= y[:,::2].mean(axis=1, keepdims=True)
    y[:,1::2] -= y[:,1::2].mean(axis=1, keepdims=True)
    return y
trainy = mean_to_0(trainy)
validy = mean_to_0(validy)
testy  = mean_to_0(testy )

# %%
scalerX = sklearn.preprocessing.MinMaxScaler().fit(trainX.reshape((trainX.shape[0], -1)))
scalerX_extra = sklearn.preprocessing.MinMaxScaler().fit(trainX_extra)
scalery = sklearn.preprocessing.MinMaxScaler().fit(trainy)

# %%
def scale_data(X, X_extra, y):
    X = scalerX.transform(X.reshape((X.shape[0],-1))).reshape((X.shape[0], look_back, -1))
    X_extra = scalerX_extra.transform(X_extra)
    y = scalery.transform(y)
    return X, X_extra, y

# %%
trainX, trainX_extra, trainy = scale_data(trainX, trainX_extra, trainy)

# %%
validX, validX_extra, validy = scale_data(validX, validX_extra, validy)

# %%
testX , testX_extra , testy  = scale_data(testX , testX_extra , testy )

# %% [markdown]
# # Print Helper

# %%
def print_mouths(gt=None, pred=None):
    def print_mouth(points, color):
        if points is None:
            return
        points = scalery.inverse_transform([points])[0]
        x = points[::2]
        y = -points[1::2]
        plt.plot(x[:12],y[:12],color)
        plt.plot(x[[0,11]],y[[0,11]],color)
        plt.plot(x[[0,12]],y[[0,12]],color)
        plt.plot(x[[6,16]],y[[6,16]],color)
        plt.plot(x[[19,12]],y[[19,12]],color)
        plt.plot(x[12:20], y[12:20],color)
    print_mouth(gt,   'b')
    print_mouth(pred, 'r')
    
    custom_lines = [plt.Line2D([0], [0], color='b', lw=4),
                plt.Line2D([0], [0], color='r', lw=4)]
    plt.legend(custom_lines, ['Ground Truth', 'Prediction'])

# %% [markdown]
# # Combined Model

# %%
def create_combined_model():
    face_input =Input(shape=(48*2,),          name='face_input',  dtype='float32')
    audio_input=Input(shape=(look_back, 39,), name='audio_input', dtype='float32')
    
    # face layers:
    face=Dense(32, activation='sigmoid',               name='face_dense_1')     (face_input)    
    face=Dropout(0.4,                                  name='face_dropout_1')   (face)
    face=Dense(5,                                      name='face_dense_2')     (face)
    
    face_only_output = Dense(40, activation='sigmoid', name='face_only_output') (face)
        
    # audio layer:
    audio = TimeDistributed(
        Dense(30, activation='sigmoid',    name='audio_TD_1'))      (audio_input)
    audio = Dropout(0.2,                   name='audio_dropout_1') (audio)
    audio = LSTM(25,return_sequences=True, name='audio_lstm_1')    (audio)
    audio = Reshape((1,look_back,25),      name='audio_reshape_1') (audio)
    audio = Dropout(0.4,                   name='audio_dropout_2') (audio)
    audio = Conv2D(20, kernel_size=(25,25), strides=5, activation='sigmoid',
       data_format='channels_first',       name='audio_conv2d_1')  (audio)
    audio = Flatten(                       name='audio_flatten_1') (audio)
    audio = Dropout(0.4,                   name='audio_dropout_3') (audio)
    audio = Dense(5, activation='sigmoid', name='audio_dense_1')   (audio)
    
    audio_boosting = Dense(40, 
        activation='sigmoid',              name='audio_boosting')   (audio)
    audio_boosting = Lambda(lambda x:x*2-1,name='audio_boosting_lambda')(
                                                                    audio_boosting)
    audio_boosting_output=keras.layers.Add(name='audio_boosting_output')(
                                                                    [face_only_output, audio_boosting])
        
    #concatenate_layer:
    conc = concatenate([audio, face],      name='concatenation_1')
    conc = Dense(20, activation='sigmoid', name='conc_dense_1') (conc)
    
    conc_output = Dense(40,
        activation='sigmoid',              name='conc_output')  (conc)

    model_combined  = Model(inputs=[audio_input, face_input],
                            outputs=[face_only_output, audio_boosting_output, conc_output])
    return model_combined

model_combined = create_combined_model()
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model_combined.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# audio_input (InputLayer)        (None, 100, 39)      0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 100, 30)      1200        audio_input[0][0]
# __________________________________________________________________________________________________
# audio_dropout_1 (Dropout)       (None, 100, 30)      0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# audio_lstm_1 (LSTM)             (None, 100, 25)      5600        audio_dropout_1[0][0]
# __________________________________________________________________________________________________
# audio_reshape_1 (Reshape)       (None, 1, 100, 25)   0           audio_lstm_1[0][0]
# __________________________________________________________________________________________________
# audio_dropout_2 (Dropout)       (None, 1, 100, 25)   0           audio_reshape_1[0][0]
# __________________________________________________________________________________________________
# face_input (InputLayer)         (None, 96)           0
# __________________________________________________________________________________________________
# audio_conv2d_1 (Conv2D)         (None, 20, 16, 1)    12520       audio_dropout_2[0][0]
# __________________________________________________________________________________________________
# face_dense_1 (Dense)            (None, 32)           3104        face_input[0][0]
# __________________________________________________________________________________________________
# audio_flatten_1 (Flatten)       (None, 320)          0           audio_conv2d_1[0][0]
# __________________________________________________________________________________________________
# face_dropout_1 (Dropout)        (None, 32)           0           face_dense_1[0][0]
# __________________________________________________________________________________________________
# audio_dropout_3 (Dropout)       (None, 320)          0           audio_flatten_1[0][0]
# __________________________________________________________________________________________________
# face_dense_2 (Dense)            (None, 5)            165         face_dropout_1[0][0]
# __________________________________________________________________________________________________
# audio_dense_1 (Dense)           (None, 5)            1605        audio_dropout_3[0][0]
# __________________________________________________________________________________________________
# audio_boosting (Dense)          (None, 40)           240         audio_dense_1[0][0]
# __________________________________________________________________________________________________
# concatenation_1 (Concatenate)   (None, 10)           0           audio_dense_1[0][0]
#                                                                  face_dense_2[0][0]
# __________________________________________________________________________________________________
# face_only_output (Dense)        (None, 40)           240         face_dense_2[0][0]
# __________________________________________________________________________________________________
# audio_boosting_lambda (Lambda)  (None, 40)           0           audio_boosting[0][0]
# __________________________________________________________________________________________________
# conc_dense_1 (Dense)            (None, 20)           220         concatenation_1[0][0]
# __________________________________________________________________________________________________
# audio_boosting_output (Add)     (None, 40)           0           face_only_output[0][0]
#                                                                  audio_boosting_lambda[0][0]
# __________________________________________________________________________________________________
# conc_output (Dense)             (None, 40)           840         conc_dense_1[0][0]
# ==================================================================================================
# Total params: 25,734
# Trainable params: 25,734
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model_combined, to_file='model_combined_plot.png', show_shapes=True, show_layer_names=True)
Image(retina=True, filename='model_combined_plot.png')

# %% [markdown]
# #  Training

# %%
model_combined.compile(optimizer='rmsprop', 
                       loss={'face_only_output':'mae', 'audio_boosting_output':'mae', 'conc_output':'mae'},
                       loss_weights={'face_only_output':.1, 'audio_boosting_output':.2, 'conc_output':.7})
history = model_combined.fit({'audio_input': trainX, 'face_input': trainX_extra}, 
                             {'face_only_output':trainy, 'audio_boosting_output':trainy, 'conc_output':trainy},
    epochs = 200, batch_size = 256, verbose = 1, shuffle = True,
        callbacks = [ModelCheckpoint('checkpoint_combined_model.h5'),
           ModelCheckpoint('checkpoint_combined_model_best_1.h5', save_best_only=True, 
                           monitor='val_conc_output_loss')],
             validation_data=({'audio_input': validX, 'face_input': validX_extra},
               {'face_only_output':validy, 'audio_boosting_output':validy, 'conc_output':validy}))
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 53839 samples, validate on 2301 samples
# Epoch 1/200
# 53839/53839 [==============================] - 34s 622us/step - loss: 0.0846 - face_only_output_loss: 0.0875 - audio_boosting_output_loss: 0.0828 - conc_output_loss: 0.0846 - val_loss: 0.0620 - val_face_only_output_loss: 0.0651 - val_audio_boosting_output_loss: 0.0618 - val_conc_output_loss: 0.0617
# Epoch 2/200
# 53839/53839 [==============================] - 32s 595us/step - loss: 0.0618 - face_only_output_loss: 0.0649 - audio_boosting_output_loss: 0.0628 - conc_output_loss: 0.0610 - val_loss: 0.0547 - val_face_only_output_loss: 0.0553 - val_audio_boosting_output_loss: 0.0550 - val_conc_output_loss: 0.0546
# Epoch 3/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0558 - face_only_output_loss: 0.0590 - audio_boosting_output_loss: 0.0585 - conc_output_loss: 0.0546 - val_loss: 0.0493 - val_face_only_output_loss: 0.0521 - val_audio_boosting_output_loss: 0.0520 - val_conc_output_loss: 0.0481
# Epoch 4/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0523 - face_only_output_loss: 0.0552 - audio_boosting_output_loss: 0.0551 - conc_output_loss: 0.0511 - val_loss: 0.0468 - val_face_only_output_loss: 0.0481 - val_audio_boosting_output_loss: 0.0481 - val_conc_output_loss: 0.0463
# Epoch 5/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0504 - face_only_output_loss: 0.0522 - audio_boosting_output_loss: 0.0520 - conc_output_loss: 0.0497 - val_loss: 0.0456 - val_face_only_output_loss: 0.0462 - val_audio_boosting_output_loss: 0.0460 - val_conc_output_loss: 0.0455
# Epoch 6/200
# 53839/53839 [==============================] - 33s 615us/step - loss: 0.0494 - face_only_output_loss: 0.0509 - audio_boosting_output_loss: 0.0506 - conc_output_loss: 0.0488 - val_loss: 0.0444 - val_face_only_output_loss: 0.0448 - val_audio_boosting_output_loss: 0.0444 - val_conc_output_loss: 0.0443
# Epoch 7/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0484 - face_only_output_loss: 0.0501 - audio_boosting_output_loss: 0.0494 - conc_output_loss: 0.0478 - val_loss: 0.0431 - val_face_only_output_loss: 0.0439 - val_audio_boosting_output_loss: 0.0430 - val_conc_output_loss: 0.0430
# Epoch 8/200
# 53839/53839 [==============================] - 32s 589us/step - loss: 0.0474 - face_only_output_loss: 0.0496 - audio_boosting_output_loss: 0.0486 - conc_output_loss: 0.0468 - val_loss: 0.0421 - val_face_only_output_loss: 0.0437 - val_audio_boosting_output_loss: 0.0422 - val_conc_output_loss: 0.0418
# Epoch 9/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0467 - face_only_output_loss: 0.0493 - audio_boosting_output_loss: 0.0481 - conc_output_loss: 0.0459 - val_loss: 0.0420 - val_face_only_output_loss: 0.0433 - val_audio_boosting_output_loss: 0.0424 - val_conc_output_loss: 0.0417
# Epoch 10/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0462 - face_only_output_loss: 0.0491 - audio_boosting_output_loss: 0.0478 - conc_output_loss: 0.0453 - val_loss: 0.0415 - val_face_only_output_loss: 0.0430 - val_audio_boosting_output_loss: 0.0425 - val_conc_output_loss: 0.0411
# Epoch 11/200
# 53839/53839 [==============================] - 32s 594us/step - loss: 0.0459 - face_only_output_loss: 0.0491 - audio_boosting_output_loss: 0.0476 - conc_output_loss: 0.0449 - val_loss: 0.0405 - val_face_only_output_loss: 0.0430 - val_audio_boosting_output_loss: 0.0411 - val_conc_output_loss: 0.0400
# Epoch 12/200
# 53839/53839 [==============================] - 32s 590us/step - loss: 0.0455 - face_only_output_loss: 0.0490 - audio_boosting_output_loss: 0.0475 - conc_output_loss: 0.0444 - val_loss: 0.0408 - val_face_only_output_loss: 0.0430 - val_audio_boosting_output_loss: 0.0417 - val_conc_output_loss: 0.0402
# Epoch 13/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0451 - face_only_output_loss: 0.0489 - audio_boosting_output_loss: 0.0472 - conc_output_loss: 0.0439 - val_loss: 0.0401 - val_face_only_output_loss: 0.0429 - val_audio_boosting_output_loss: 0.0416 - val_conc_output_loss: 0.0393
# Epoch 14/200
# 53839/53839 [==============================] - 31s 576us/step - loss: 0.0448 - face_only_output_loss: 0.0488 - audio_boosting_output_loss: 0.0471 - conc_output_loss: 0.0435 - val_loss: 0.0399 - val_face_only_output_loss: 0.0433 - val_audio_boosting_output_loss: 0.0415 - val_conc_output_loss: 0.0390
# Epoch 15/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0446 - face_only_output_loss: 0.0488 - audio_boosting_output_loss: 0.0471 - conc_output_loss: 0.0432 - val_loss: 0.0395 - val_face_only_output_loss: 0.0433 - val_audio_boosting_output_loss: 0.0414 - val_conc_output_loss: 0.0384
# Epoch 16/200
# 53839/53839 [==============================] - 33s 615us/step - loss: 0.0444 - face_only_output_loss: 0.0487 - audio_boosting_output_loss: 0.0469 - conc_output_loss: 0.0430 - val_loss: 0.0394 - val_face_only_output_loss: 0.0431 - val_audio_boosting_output_loss: 0.0414 - val_conc_output_loss: 0.0383
# Epoch 17/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0442 - face_only_output_loss: 0.0486 - audio_boosting_output_loss: 0.0467 - conc_output_loss: 0.0428 - val_loss: 0.0392 - val_face_only_output_loss: 0.0431 - val_audio_boosting_output_loss: 0.0412 - val_conc_output_loss: 0.0380
# Epoch 18/200
# 53839/53839 [==============================] - 32s 588us/step - loss: 0.0440 - face_only_output_loss: 0.0486 - audio_boosting_output_loss: 0.0466 - conc_output_loss: 0.0426 - val_loss: 0.0392 - val_face_only_output_loss: 0.0429 - val_audio_boosting_output_loss: 0.0411 - val_conc_output_loss: 0.0381
# Epoch 19/200
# 53839/53839 [==============================] - 32s 589us/step - loss: 0.0439 - face_only_output_loss: 0.0486 - audio_boosting_output_loss: 0.0466 - conc_output_loss: 0.0425 - val_loss: 0.0390 - val_face_only_output_loss: 0.0429 - val_audio_boosting_output_loss: 0.0410 - val_conc_output_loss: 0.0379
# Epoch 20/200
# 53839/53839 [==============================] - 32s 585us/step - loss: 0.0438 - face_only_output_loss: 0.0486 - audio_boosting_output_loss: 0.0465 - conc_output_loss: 0.0424 - val_loss: 0.0395 - val_face_only_output_loss: 0.0426 - val_audio_boosting_output_loss: 0.0415 - val_conc_output_loss: 0.0385
# Epoch 21/200
# 53839/53839 [==============================] - 32s 597us/step - loss: 0.0436 - face_only_output_loss: 0.0484 - audio_boosting_output_loss: 0.0463 - conc_output_loss: 0.0422 - val_loss: 0.0384 - val_face_only_output_loss: 0.0426 - val_audio_boosting_output_loss: 0.0402 - val_conc_output_loss: 0.0373
# Epoch 22/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0435 - face_only_output_loss: 0.0484 - audio_boosting_output_loss: 0.0462 - conc_output_loss: 0.0420 - val_loss: 0.0393 - val_face_only_output_loss: 0.0430 - val_audio_boosting_output_loss: 0.0413 - val_conc_output_loss: 0.0382
# Epoch 23/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0435 - face_only_output_loss: 0.0485 - audio_boosting_output_loss: 0.0462 - conc_output_loss: 0.0420 - val_loss: 0.0385 - val_face_only_output_loss: 0.0425 - val_audio_boosting_output_loss: 0.0403 - val_conc_output_loss: 0.0374
# Epoch 24/200
# 53839/53839 [==============================] - 31s 579us/step - loss: 0.0433 - face_only_output_loss: 0.0484 - audio_boosting_output_loss: 0.0460 - conc_output_loss: 0.0418 - val_loss: 0.0383 - val_face_only_output_loss: 0.0425 - val_audio_boosting_output_loss: 0.0400 - val_conc_output_loss: 0.0372
# Epoch 25/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0432 - face_only_output_loss: 0.0483 - audio_boosting_output_loss: 0.0460 - conc_output_loss: 0.0417 - val_loss: 0.0380 - val_face_only_output_loss: 0.0423 - val_audio_boosting_output_loss: 0.0397 - val_conc_output_loss: 0.0370
# Epoch 26/200
# 53839/53839 [==============================] - 33s 610us/step - loss: 0.0431 - face_only_output_loss: 0.0483 - audio_boosting_output_loss: 0.0458 - conc_output_loss: 0.0416 - val_loss: 0.0383 - val_face_only_output_loss: 0.0421 - val_audio_boosting_output_loss: 0.0400 - val_conc_output_loss: 0.0373
# Epoch 27/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0430 - face_only_output_loss: 0.0482 - audio_boosting_output_loss: 0.0457 - conc_output_loss: 0.0414 - val_loss: 0.0379 - val_face_only_output_loss: 0.0423 - val_audio_boosting_output_loss: 0.0396 - val_conc_output_loss: 0.0367
# Epoch 28/200
# 53839/53839 [==============================] - 32s 588us/step - loss: 0.0429 - face_only_output_loss: 0.0481 - audio_boosting_output_loss: 0.0456 - conc_output_loss: 0.0414 - val_loss: 0.0379 - val_face_only_output_loss: 0.0424 - val_audio_boosting_output_loss: 0.0398 - val_conc_output_loss: 0.0368
# Epoch 29/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0429 - face_only_output_loss: 0.0481 - audio_boosting_output_loss: 0.0456 - conc_output_loss: 0.0413 - val_loss: 0.0379 - val_face_only_output_loss: 0.0425 - val_audio_boosting_output_loss: 0.0399 - val_conc_output_loss: 0.0366
# Epoch 30/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0428 - face_only_output_loss: 0.0481 - audio_boosting_output_loss: 0.0455 - conc_output_loss: 0.0412 - val_loss: 0.0379 - val_face_only_output_loss: 0.0425 - val_audio_boosting_output_loss: 0.0398 - val_conc_output_loss: 0.0366
# Epoch 31/200
# 53839/53839 [==============================] - 32s 593us/step - loss: 0.0427 - face_only_output_loss: 0.0481 - audio_boosting_output_loss: 0.0454 - conc_output_loss: 0.0411 - val_loss: 0.0382 - val_face_only_output_loss: 0.0426 - val_audio_boosting_output_loss: 0.0401 - val_conc_output_loss: 0.0370
# Epoch 32/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0426 - face_only_output_loss: 0.0479 - audio_boosting_output_loss: 0.0453 - conc_output_loss: 0.0410 - val_loss: 0.0378 - val_face_only_output_loss: 0.0425 - val_audio_boosting_output_loss: 0.0398 - val_conc_output_loss: 0.0366
# Epoch 33/200
# 53839/53839 [==============================] - 31s 579us/step - loss: 0.0424 - face_only_output_loss: 0.0479 - audio_boosting_output_loss: 0.0452 - conc_output_loss: 0.0409 - val_loss: 0.0383 - val_face_only_output_loss: 0.0421 - val_audio_boosting_output_loss: 0.0402 - val_conc_output_loss: 0.0373
# Epoch 34/200
# 53839/53839 [==============================] - 31s 577us/step - loss: 0.0424 - face_only_output_loss: 0.0479 - audio_boosting_output_loss: 0.0452 - conc_output_loss: 0.0409 - val_loss: 0.0375 - val_face_only_output_loss: 0.0423 - val_audio_boosting_output_loss: 0.0394 - val_conc_output_loss: 0.0362
# Epoch 35/200
# 53839/53839 [==============================] - 32s 585us/step - loss: 0.0424 - face_only_output_loss: 0.0479 - audio_boosting_output_loss: 0.0452 - conc_output_loss: 0.0408 - val_loss: 0.0375 - val_face_only_output_loss: 0.0423 - val_audio_boosting_output_loss: 0.0395 - val_conc_output_loss: 0.0362
# Epoch 36/200
# 53839/53839 [==============================] - 33s 607us/step - loss: 0.0422 - face_only_output_loss: 0.0478 - audio_boosting_output_loss: 0.0450 - conc_output_loss: 0.0406 - val_loss: 0.0372 - val_face_only_output_loss: 0.0418 - val_audio_boosting_output_loss: 0.0387 - val_conc_output_loss: 0.0360
# Epoch 37/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0422 - face_only_output_loss: 0.0478 - audio_boosting_output_loss: 0.0450 - conc_output_loss: 0.0406 - val_loss: 0.0374 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0389 - val_conc_output_loss: 0.0363
# Epoch 38/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0421 - face_only_output_loss: 0.0478 - audio_boosting_output_loss: 0.0449 - conc_output_loss: 0.0405 - val_loss: 0.0373 - val_face_only_output_loss: 0.0418 - val_audio_boosting_output_loss: 0.0391 - val_conc_output_loss: 0.0362
# Epoch 39/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0421 - face_only_output_loss: 0.0478 - audio_boosting_output_loss: 0.0449 - conc_output_loss: 0.0404 - val_loss: 0.0374 - val_face_only_output_loss: 0.0420 - val_audio_boosting_output_loss: 0.0392 - val_conc_output_loss: 0.0362
# Epoch 40/200
# 53839/53839 [==============================] - 32s 593us/step - loss: 0.0420 - face_only_output_loss: 0.0477 - audio_boosting_output_loss: 0.0449 - conc_output_loss: 0.0404 - val_loss: 0.0370 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0387 - val_conc_output_loss: 0.0358
# Epoch 41/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0420 - face_only_output_loss: 0.0478 - audio_boosting_output_loss: 0.0448 - conc_output_loss: 0.0403 - val_loss: 0.0379 - val_face_only_output_loss: 0.0421 - val_audio_boosting_output_loss: 0.0400 - val_conc_output_loss: 0.0367
# Epoch 42/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0419 - face_only_output_loss: 0.0477 - audio_boosting_output_loss: 0.0448 - conc_output_loss: 0.0402 - val_loss: 0.0369 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0383 - val_conc_output_loss: 0.0359
# Epoch 43/200
# 53839/53839 [==============================] - 31s 585us/step - loss: 0.0418 - face_only_output_loss: 0.0477 - audio_boosting_output_loss: 0.0447 - conc_output_loss: 0.0402 - val_loss: 0.0368 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0385 - val_conc_output_loss: 0.0356
# Epoch 44/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0418 - face_only_output_loss: 0.0477 - audio_boosting_output_loss: 0.0447 - conc_output_loss: 0.0401 - val_loss: 0.0371 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0389 - val_conc_output_loss: 0.0360
# Epoch 45/200
# 53839/53839 [==============================] - 32s 591us/step - loss: 0.0417 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0447 - conc_output_loss: 0.0400 - val_loss: 0.0376 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0392 - val_conc_output_loss: 0.0365
# Epoch 46/200
# 53839/53839 [==============================] - 32s 598us/step - loss: 0.0417 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0446 - conc_output_loss: 0.0400 - val_loss: 0.0366 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0384 - val_conc_output_loss: 0.0353
# Epoch 47/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0416 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0446 - conc_output_loss: 0.0399 - val_loss: 0.0369 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0385 - val_conc_output_loss: 0.0358
# Epoch 48/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0415 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0445 - conc_output_loss: 0.0398 - val_loss: 0.0368 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0385 - val_conc_output_loss: 0.0357
# Epoch 49/200
# 53839/53839 [==============================] - 31s 578us/step - loss: 0.0415 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0445 - conc_output_loss: 0.0398 - val_loss: 0.0368 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0386 - val_conc_output_loss: 0.0357
# Epoch 50/200
# 53839/53839 [==============================] - 32s 591us/step - loss: 0.0414 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0444 - conc_output_loss: 0.0397 - val_loss: 0.0368 - val_face_only_output_loss: 0.0418 - val_audio_boosting_output_loss: 0.0388 - val_conc_output_loss: 0.0356
# Epoch 51/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0414 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0445 - conc_output_loss: 0.0396 - val_loss: 0.0367 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0384 - val_conc_output_loss: 0.0355
# Epoch 52/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0414 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0445 - conc_output_loss: 0.0396 - val_loss: 0.0368 - val_face_only_output_loss: 0.0418 - val_audio_boosting_output_loss: 0.0387 - val_conc_output_loss: 0.0355
# Epoch 53/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0414 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0444 - conc_output_loss: 0.0396 - val_loss: 0.0365 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0384 - val_conc_output_loss: 0.0352
# Epoch 54/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0412 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0444 - conc_output_loss: 0.0394 - val_loss: 0.0380 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0394 - val_conc_output_loss: 0.0370
# Epoch 55/200
# 53839/53839 [==============================] - 33s 611us/step - loss: 0.0412 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0443 - conc_output_loss: 0.0394 - val_loss: 0.0365 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0383 - val_conc_output_loss: 0.0353
# Epoch 56/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0411 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0443 - conc_output_loss: 0.0393 - val_loss: 0.0364 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0382 - val_conc_output_loss: 0.0352
# Epoch 57/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0411 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0442 - conc_output_loss: 0.0392 - val_loss: 0.0365 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0383 - val_conc_output_loss: 0.0353
# Epoch 58/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0411 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0443 - conc_output_loss: 0.0392 - val_loss: 0.0367 - val_face_only_output_loss: 0.0419 - val_audio_boosting_output_loss: 0.0387 - val_conc_output_loss: 0.0354
# Epoch 59/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0410 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0442 - conc_output_loss: 0.0392 - val_loss: 0.0365 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0383 - val_conc_output_loss: 0.0352
# Epoch 60/200
# 53839/53839 [==============================] - 32s 590us/step - loss: 0.0411 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0443 - conc_output_loss: 0.0392 - val_loss: 0.0363 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0381 - val_conc_output_loss: 0.0350
# Epoch 61/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0409 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0441 - conc_output_loss: 0.0390 - val_loss: 0.0362 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0380 - val_conc_output_loss: 0.0350
# Epoch 62/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0408 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0440 - conc_output_loss: 0.0390 - val_loss: 0.0364 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0383 - val_conc_output_loss: 0.0351
# Epoch 63/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0409 - face_only_output_loss: 0.0476 - audio_boosting_output_loss: 0.0442 - conc_output_loss: 0.0390 - val_loss: 0.0362 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0379 - val_conc_output_loss: 0.0350
# Epoch 64/200
# 53839/53839 [==============================] - 31s 580us/step - loss: 0.0408 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0442 - conc_output_loss: 0.0389 - val_loss: 0.0364 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0384 - val_conc_output_loss: 0.0350
# Epoch 65/200
# 53839/53839 [==============================] - 33s 613us/step - loss: 0.0408 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0441 - conc_output_loss: 0.0389 - val_loss: 0.0362 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0381 - val_conc_output_loss: 0.0348
# Epoch 66/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0408 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0441 - conc_output_loss: 0.0389 - val_loss: 0.0363 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0382 - val_conc_output_loss: 0.0350
# Epoch 67/200
# 53839/53839 [==============================] - 31s 585us/step - loss: 0.0407 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0440 - conc_output_loss: 0.0388 - val_loss: 0.0371 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0389 - val_conc_output_loss: 0.0360
# Epoch 68/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0407 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0440 - conc_output_loss: 0.0387 - val_loss: 0.0361 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0381 - val_conc_output_loss: 0.0348
# Epoch 69/200
# 53839/53839 [==============================] - 32s 591us/step - loss: 0.0407 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0440 - conc_output_loss: 0.0388 - val_loss: 0.0363 - val_face_only_output_loss: 0.0411 - val_audio_boosting_output_loss: 0.0380 - val_conc_output_loss: 0.0351
# Epoch 70/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0406 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0439 - conc_output_loss: 0.0387 - val_loss: 0.0365 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0385 - val_conc_output_loss: 0.0352
# Epoch 71/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0406 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0440 - conc_output_loss: 0.0386 - val_loss: 0.0358 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0346
# Epoch 72/200
# 53839/53839 [==============================] - 32s 588us/step - loss: 0.0406 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0440 - conc_output_loss: 0.0386 - val_loss: 0.0363 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0381 - val_conc_output_loss: 0.0351
# Epoch 73/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0405 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0439 - conc_output_loss: 0.0385 - val_loss: 0.0362 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0382 - val_conc_output_loss: 0.0348
# Epoch 74/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0405 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0439 - conc_output_loss: 0.0385 - val_loss: 0.0361 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0380 - val_conc_output_loss: 0.0348
# Epoch 75/200
# 53839/53839 [==============================] - 33s 605us/step - loss: 0.0404 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0438 - conc_output_loss: 0.0385 - val_loss: 0.0359 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0379 - val_conc_output_loss: 0.0346
# Epoch 76/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0405 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0439 - conc_output_loss: 0.0385 - val_loss: 0.0360 - val_face_only_output_loss: 0.0419 - val_audio_boosting_output_loss: 0.0384 - val_conc_output_loss: 0.0345
# Epoch 77/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0404 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0438 - conc_output_loss: 0.0384 - val_loss: 0.0365 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0382 - val_conc_output_loss: 0.0353
# Epoch 78/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0403 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0438 - conc_output_loss: 0.0384 - val_loss: 0.0360 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0381 - val_conc_output_loss: 0.0346
# Epoch 79/200
# 53839/53839 [==============================] - 32s 589us/step - loss: 0.0404 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0439 - conc_output_loss: 0.0384 - val_loss: 0.0360 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0379 - val_conc_output_loss: 0.0348
# Epoch 80/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0403 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0437 - conc_output_loss: 0.0383 - val_loss: 0.0359 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0379 - val_conc_output_loss: 0.0346
# Epoch 81/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0403 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0438 - conc_output_loss: 0.0383 - val_loss: 0.0360 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0384 - val_conc_output_loss: 0.0345
# Epoch 82/200
# 53839/53839 [==============================] - 31s 576us/step - loss: 0.0402 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0438 - conc_output_loss: 0.0382 - val_loss: 0.0359 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0380 - val_conc_output_loss: 0.0345
# Epoch 83/200
# 53839/53839 [==============================] - 32s 588us/step - loss: 0.0402 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0437 - conc_output_loss: 0.0382 - val_loss: 0.0356 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0378 - val_conc_output_loss: 0.0341
# Epoch 84/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0402 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0437 - conc_output_loss: 0.0382 - val_loss: 0.0360 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0382 - val_conc_output_loss: 0.0346
# Epoch 85/200
# 53839/53839 [==============================] - 33s 618us/step - loss: 0.0402 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0438 - conc_output_loss: 0.0382 - val_loss: 0.0359 - val_face_only_output_loss: 0.0410 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0346
# Epoch 86/200
# 53839/53839 [==============================] - 31s 585us/step - loss: 0.0402 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0437 - conc_output_loss: 0.0382 - val_loss: 0.0359 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0377 - val_conc_output_loss: 0.0346
# Epoch 87/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0401 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0380 - val_loss: 0.0356 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0378 - val_conc_output_loss: 0.0342
# Epoch 88/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0401 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0437 - conc_output_loss: 0.0381 - val_loss: 0.0358 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0345
# Epoch 89/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0401 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0381 - val_loss: 0.0357 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0378 - val_conc_output_loss: 0.0343
# Epoch 90/200
# 53839/53839 [==============================] - 31s 578us/step - loss: 0.0401 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0380 - val_loss: 0.0356 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0341
# Epoch 91/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0400 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0380 - val_loss: 0.0355 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0342
# Epoch 92/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0401 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0437 - conc_output_loss: 0.0380 - val_loss: 0.0355 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0341
# Epoch 93/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0400 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0379 - val_loss: 0.0358 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0377 - val_conc_output_loss: 0.0344
# Epoch 94/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0400 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0379 - val_loss: 0.0356 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0377 - val_conc_output_loss: 0.0341
# Epoch 95/200
# 53839/53839 [==============================] - 33s 612us/step - loss: 0.0400 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0379 - val_loss: 0.0354 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0340
# Epoch 96/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0400 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0378 - val_loss: 0.0360 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0380 - val_conc_output_loss: 0.0347
# Epoch 97/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0400 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0379 - val_loss: 0.0355 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0341
# Epoch 98/200
# 53839/53839 [==============================] - 32s 589us/step - loss: 0.0399 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0378 - val_loss: 0.0355 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0378 - val_conc_output_loss: 0.0339
# Epoch 99/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0398 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0435 - conc_output_loss: 0.0377 - val_loss: 0.0358 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0381 - val_conc_output_loss: 0.0344
# Epoch 100/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0399 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0435 - conc_output_loss: 0.0377 - val_loss: 0.0358 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0378 - val_conc_output_loss: 0.0344
# Epoch 101/200
# 53839/53839 [==============================] - 31s 585us/step - loss: 0.0398 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0435 - conc_output_loss: 0.0377 - val_loss: 0.0357 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0343
# Epoch 102/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0398 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0435 - conc_output_loss: 0.0377 - val_loss: 0.0353 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0339
# Epoch 103/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0398 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0435 - conc_output_loss: 0.0377 - val_loss: 0.0356 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0341
# Epoch 104/200
# 53839/53839 [==============================] - 33s 607us/step - loss: 0.0397 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0435 - conc_output_loss: 0.0376 - val_loss: 0.0358 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0380 - val_conc_output_loss: 0.0343
# Epoch 105/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0397 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0376 - val_loss: 0.0353 - val_face_only_output_loss: 0.0411 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0339
# Epoch 106/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0398 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0435 - conc_output_loss: 0.0377 - val_loss: 0.0356 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0379 - val_conc_output_loss: 0.0341
# Epoch 107/200
# 53839/53839 [==============================] - 31s 579us/step - loss: 0.0397 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0375 - val_loss: 0.0351 - val_face_only_output_loss: 0.0410 - val_audio_boosting_output_loss: 0.0369 - val_conc_output_loss: 0.0337
# Epoch 108/200
# 53839/53839 [==============================] - 32s 589us/step - loss: 0.0397 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0435 - conc_output_loss: 0.0375 - val_loss: 0.0353 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0339
# Epoch 109/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0398 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0436 - conc_output_loss: 0.0376 - val_loss: 0.0358 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0380 - val_conc_output_loss: 0.0344
# Epoch 110/200
# 53839/53839 [==============================] - 32s 588us/step - loss: 0.0397 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0375 - val_loss: 0.0357 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0343
# Epoch 111/200
# 53839/53839 [==============================] - 32s 585us/step - loss: 0.0397 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0375 - val_loss: 0.0358 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0345
# Epoch 112/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0396 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0375 - val_loss: 0.0353 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0337
# Epoch 113/200
# 53839/53839 [==============================] - 31s 577us/step - loss: 0.0397 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0435 - conc_output_loss: 0.0375 - val_loss: 0.0353 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0338
# Epoch 114/200
# 53839/53839 [==============================] - 33s 611us/step - loss: 0.0396 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0374 - val_loss: 0.0355 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0377 - val_conc_output_loss: 0.0341
# Epoch 115/200
# 53839/53839 [==============================] - 31s 580us/step - loss: 0.0396 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0374 - val_loss: 0.0352 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0337
# Epoch 116/200
# 53839/53839 [==============================] - 31s 579us/step - loss: 0.0396 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0374 - val_loss: 0.0353 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0338
# Epoch 117/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0395 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0374 - val_loss: 0.0352 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0338
# Epoch 118/200
# 53839/53839 [==============================] - 32s 592us/step - loss: 0.0395 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0373 - val_loss: 0.0354 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0340
# Epoch 119/200
# 53839/53839 [==============================] - 32s 588us/step - loss: 0.0396 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0374 - val_loss: 0.0352 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0337
# Epoch 120/200
# 53839/53839 [==============================] - 32s 591us/step - loss: 0.0395 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0373 - val_loss: 0.0353 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0338
# Epoch 121/200
# 53839/53839 [==============================] - 32s 588us/step - loss: 0.0395 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0373 - val_loss: 0.0352 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0338
# Epoch 122/200
# 53839/53839 [==============================] - 32s 588us/step - loss: 0.0396 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0373 - val_loss: 0.0362 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0384 - val_conc_output_loss: 0.0348
# Epoch 123/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0395 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0373 - val_loss: 0.0356 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0377 - val_conc_output_loss: 0.0342
# Epoch 124/200
# 53839/53839 [==============================] - 33s 609us/step - loss: 0.0394 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0372 - val_loss: 0.0352 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0337
# Epoch 125/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0395 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0372 - val_loss: 0.0351 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0371 - val_conc_output_loss: 0.0336
# Epoch 126/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0395 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0372 - val_loss: 0.0351 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0371 - val_conc_output_loss: 0.0336
# Epoch 127/200
# 53839/53839 [==============================] - 32s 593us/step - loss: 0.0394 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0372 - val_loss: 0.0356 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0378 - val_conc_output_loss: 0.0341
# Epoch 128/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0394 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0372 - val_loss: 0.0355 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0377 - val_conc_output_loss: 0.0340
# Epoch 129/200
# 53839/53839 [==============================] - 32s 590us/step - loss: 0.0394 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0371 - val_loss: 0.0352 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0337
# Epoch 130/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0394 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0434 - conc_output_loss: 0.0372 - val_loss: 0.0351 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0336
# Epoch 131/200
# 53839/53839 [==============================] - 31s 585us/step - loss: 0.0394 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0371 - val_loss: 0.0356 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0342
# Epoch 132/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0393 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0371 - val_loss: 0.0352 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0338
# Epoch 133/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0394 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0371 - val_loss: 0.0353 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0338
# Epoch 134/200
# 53839/53839 [==============================] - 33s 609us/step - loss: 0.0393 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0370 - val_loss: 0.0354 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0338
# Epoch 135/200
# 53839/53839 [==============================] - 31s 580us/step - loss: 0.0393 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0370 - val_loss: 0.0351 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0335
# Epoch 136/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0393 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0370 - val_loss: 0.0354 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0339
# Epoch 137/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0393 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0370 - val_loss: 0.0352 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0336
# Epoch 138/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0392 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0369 - val_loss: 0.0351 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0336
# Epoch 139/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0393 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0370 - val_loss: 0.0352 - val_face_only_output_loss: 0.0410 - val_audio_boosting_output_loss: 0.0369 - val_conc_output_loss: 0.0339
# Epoch 140/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0393 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0370 - val_loss: 0.0352 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0337
# Epoch 141/200
# 53839/53839 [==============================] - 31s 579us/step - loss: 0.0392 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0369 - val_loss: 0.0351 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0371 - val_conc_output_loss: 0.0336
# Epoch 142/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0392 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0369 - val_loss: 0.0350 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0371 - val_conc_output_loss: 0.0335
# Epoch 143/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0392 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0369 - val_loss: 0.0351 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0337
# Epoch 144/200
# 53839/53839 [==============================] - 33s 612us/step - loss: 0.0392 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0369 - val_loss: 0.0352 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0336
# Epoch 145/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0392 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0369 - val_loss: 0.0352 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0336
# Epoch 146/200
# 53839/53839 [==============================] - 32s 589us/step - loss: 0.0392 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0433 - conc_output_loss: 0.0369 - val_loss: 0.0350 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0334
# Epoch 147/200
# 53839/53839 [==============================] - 32s 592us/step - loss: 0.0392 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0369 - val_loss: 0.0350 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0334
# Epoch 148/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0392 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0368 - val_loss: 0.0354 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0377 - val_conc_output_loss: 0.0338
# Epoch 149/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0391 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0368 - val_loss: 0.0349 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0334
# Epoch 150/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0391 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0368 - val_loss: 0.0357 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0380 - val_conc_output_loss: 0.0342
# Epoch 151/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0391 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0368 - val_loss: 0.0352 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0336
# Epoch 152/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0391 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0368 - val_loss: 0.0349 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0332
# Epoch 153/200
# 53839/53839 [==============================] - 33s 605us/step - loss: 0.0391 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0367 - val_loss: 0.0353 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0377 - val_conc_output_loss: 0.0338
# Epoch 154/200
# 53839/53839 [==============================] - 32s 593us/step - loss: 0.0391 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0368 - val_loss: 0.0352 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0338
# Epoch 155/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0391 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0367 - val_loss: 0.0350 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0335
# Epoch 156/200
# 53839/53839 [==============================] - 32s 590us/step - loss: 0.0390 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0367 - val_loss: 0.0354 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0340
# Epoch 157/200
# 53839/53839 [==============================] - 31s 585us/step - loss: 0.0391 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0368 - val_loss: 0.0353 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0338
# Epoch 158/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0391 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0367 - val_loss: 0.0351 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0336
# Epoch 159/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0390 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0366 - val_loss: 0.0348 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0370 - val_conc_output_loss: 0.0333
# Epoch 160/200
# 53839/53839 [==============================] - 32s 585us/step - loss: 0.0390 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0366 - val_loss: 0.0354 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0340
# Epoch 161/200
# 53839/53839 [==============================] - 31s 579us/step - loss: 0.0390 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0366 - val_loss: 0.0348 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0370 - val_conc_output_loss: 0.0332
# Epoch 162/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0391 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0367 - val_loss: 0.0352 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0337
# Epoch 163/200
# 53839/53839 [==============================] - 33s 613us/step - loss: 0.0390 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0366 - val_loss: 0.0348 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0369 - val_conc_output_loss: 0.0332
# Epoch 164/200
# 53839/53839 [==============================] - 31s 584us/step - loss: 0.0390 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0366 - val_loss: 0.0351 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0336
# Epoch 165/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0389 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0366 - val_loss: 0.0351 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0336
# Epoch 166/200
# 53839/53839 [==============================] - 32s 593us/step - loss: 0.0390 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0366 - val_loss: 0.0351 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0334
# Epoch 167/200
# 53839/53839 [==============================] - 31s 585us/step - loss: 0.0390 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0366 - val_loss: 0.0348 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0370 - val_conc_output_loss: 0.0332
# Epoch 168/200
# 53839/53839 [==============================] - 31s 577us/step - loss: 0.0389 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0365 - val_loss: 0.0348 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0332
# Epoch 169/200
# 53839/53839 [==============================] - 31s 580us/step - loss: 0.0389 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0365 - val_loss: 0.0349 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0369 - val_conc_output_loss: 0.0334
# Epoch 170/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0389 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0365 - val_loss: 0.0350 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0335
# Epoch 171/200
# 53839/53839 [==============================] - 31s 581us/step - loss: 0.0390 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0366 - val_loss: 0.0353 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0337
# Epoch 172/200
# 53839/53839 [==============================] - 31s 580us/step - loss: 0.0389 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0365 - val_loss: 0.0350 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0333
# Epoch 173/200
# 53839/53839 [==============================] - 33s 608us/step - loss: 0.0389 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0365 - val_loss: 0.0350 - val_face_only_output_loss: 0.0418 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0332
# Epoch 174/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0389 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0365 - val_loss: 0.0351 - val_face_only_output_loss: 0.0418 - val_audio_boosting_output_loss: 0.0377 - val_conc_output_loss: 0.0334
# Epoch 175/200
# 53839/53839 [==============================] - 32s 596us/step - loss: 0.0388 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0364 - val_loss: 0.0349 - val_face_only_output_loss: 0.0418 - val_audio_boosting_output_loss: 0.0376 - val_conc_output_loss: 0.0332
# Epoch 176/200
# 53839/53839 [==============================] - 32s 585us/step - loss: 0.0389 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0365 - val_loss: 0.0351 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0335
# Epoch 177/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0388 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0364 - val_loss: 0.0349 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0332
# Epoch 178/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0389 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0365 - val_loss: 0.0348 - val_face_only_output_loss: 0.0410 - val_audio_boosting_output_loss: 0.0367 - val_conc_output_loss: 0.0333
# Epoch 179/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0388 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0364 - val_loss: 0.0347 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0369 - val_conc_output_loss: 0.0332
# Epoch 180/200
# 53839/53839 [==============================] - 32s 588us/step - loss: 0.0389 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0364 - val_loss: 0.0349 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0332
# Epoch 181/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0389 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0364 - val_loss: 0.0348 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0370 - val_conc_output_loss: 0.0333
# Epoch 182/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0389 - face_only_output_loss: 0.0475 - audio_boosting_output_loss: 0.0432 - conc_output_loss: 0.0364 - val_loss: 0.0352 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0336
# Epoch 183/200
# 53839/53839 [==============================] - 33s 614us/step - loss: 0.0388 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0364 - val_loss: 0.0348 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0374 - val_conc_output_loss: 0.0331
# Epoch 184/200
# 53839/53839 [==============================] - 31s 582us/step - loss: 0.0388 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0364 - val_loss: 0.0351 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0336
# Epoch 185/200
# 53839/53839 [==============================] - 32s 589us/step - loss: 0.0388 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0363 - val_loss: 0.0348 - val_face_only_output_loss: 0.0411 - val_audio_boosting_output_loss: 0.0369 - val_conc_output_loss: 0.0333
# Epoch 186/200
# 53839/53839 [==============================] - 31s 577us/step - loss: 0.0388 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0363 - val_loss: 0.0347 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0331
# Epoch 187/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0388 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0363 - val_loss: 0.0347 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0330
# Epoch 188/200
# 53839/53839 [==============================] - 31s 585us/step - loss: 0.0388 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0431 - conc_output_loss: 0.0363 - val_loss: 0.0348 - val_face_only_output_loss: 0.0415 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0331
# Epoch 189/200
# 53839/53839 [==============================] - 31s 579us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0362 - val_loss: 0.0349 - val_face_only_output_loss: 0.0417 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0331
# Epoch 190/200
# 53839/53839 [==============================] - 31s 579us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0363 - val_loss: 0.0346 - val_face_only_output_loss: 0.0412 - val_audio_boosting_output_loss: 0.0368 - val_conc_output_loss: 0.0330
# Epoch 191/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0387 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0429 - conc_output_loss: 0.0363 - val_loss: 0.0347 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0370 - val_conc_output_loss: 0.0331
# Epoch 192/200
# 53839/53839 [==============================] - 31s 585us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0363 - val_loss: 0.0347 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0370 - val_conc_output_loss: 0.0330
# Epoch 193/200
# 53839/53839 [==============================] - 33s 609us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0363 - val_loss: 0.0352 - val_face_only_output_loss: 0.0413 - val_audio_boosting_output_loss: 0.0373 - val_conc_output_loss: 0.0338
# Epoch 194/200
# 53839/53839 [==============================] - 31s 583us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0363 - val_loss: 0.0352 - val_face_only_output_loss: 0.0410 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0338
# Epoch 195/200
# 53839/53839 [==============================] - 32s 591us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0363 - val_loss: 0.0349 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0333
# Epoch 196/200
# 53839/53839 [==============================] - 31s 578us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0363 - val_loss: 0.0347 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0331
# Epoch 197/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0362 - val_loss: 0.0349 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0334
# Epoch 198/200
# 53839/53839 [==============================] - 32s 587us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0362 - val_loss: 0.0349 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0372 - val_conc_output_loss: 0.0333
# Epoch 199/200
# 53839/53839 [==============================] - 32s 586us/step - loss: 0.0387 - face_only_output_loss: 0.0473 - audio_boosting_output_loss: 0.0429 - conc_output_loss: 0.0362 - val_loss: 0.0346 - val_face_only_output_loss: 0.0414 - val_audio_boosting_output_loss: 0.0370 - val_conc_output_loss: 0.0330
# Epoch 200/200
# 53839/53839 [==============================] - 31s 578us/step - loss: 0.0387 - face_only_output_loss: 0.0474 - audio_boosting_output_loss: 0.0430 - conc_output_loss: 0.0362 - val_loss: 0.0351 - val_face_only_output_loss: 0.0416 - val_audio_boosting_output_loss: 0.0375 - val_conc_output_loss: 0.0335

# %%
model_combined.compile(optimizer='adam', 
                       loss={'face_only_output':'mae', 
                             'audio_boosting_output':'mae', 
                             'conc_output':'mae'},
                       loss_weights={'face_only_output':.01, 'audio_boosting_output':.01, 'conc_output':.98})
history2 = model_combined.fit({'audio_input': trainX, 'face_input': trainX_extra}, 
                             {'face_only_output':trainy, 'audio_boosting_output':trainy, 'conc_output':trainy},
    epochs = 200, batch_size = 4096, verbose = 1, shuffle = True,
        callbacks = [ModelCheckpoint('checkpoint_combined_model.h5'),
           ModelCheckpoint('checkpoint_combined_model_best_6_RMSE.h5', save_best_only=True, 
                           monitor='val_conc_output_loss')],
             validation_data=({'audio_input': validX, 'face_input': validX_extra},
               {'face_only_output':validy, 'audio_boosting_output':validy, 'conc_output':validy}))
# Out:
# Train on 134515 samples, validate on 2301 samples
# Epoch 1/200
# 134515/134515 [==============================] - 18s 130us/step - loss: 0.0336 - face_only_output_loss: 0.0506 - audio_boosting_output_loss: 0.0463 - conc_output_loss: 0.0333 - val_loss: 0.0311 - val_face_only_output_loss: 0.0459 - val_audio_boosting_output_loss: 0.0416 - val_conc_output_loss: 0.0308
# Epoch 2/200
# 134515/134515 [==============================] - 12s 91us/step - loss: 0.0336 - face_only_output_loss: 0.0506 - audio_boosting_output_loss: 0.0462 - conc_output_loss: 0.0333 - val_loss: 0.0310 - val_face_only_output_loss: 0.0462 - val_audio_boosting_output_loss: 0.0417 - val_conc_output_loss: 0.0308
# Epoch 3/200
# 134515/134515 [==============================] - 12s 90us/step - loss: 0.0335 - face_only_output_loss: 0.0506 - audio_boosting_output_loss: 0.0462 - conc_output_loss: 0.0332 - val_loss: 0.0310 - val_face_only_output_loss: 0.0461 - val_audio_boosting_output_loss: 0.0417 - val_conc_output_loss: 0.0308
# Epoch 4/200
# 134515/134515 [==============================] - 12s 90us/step - loss: 0.0335 - face_only_output_loss: 0.0506 - audio_boosting_output_loss: 0.0462 - conc_output_loss: 0.0332 - val_loss: 0.0310 - val_face_only_output_loss: 0.0461 - val_audio_boosting_output_loss: 0.0417 - val_conc_output_loss: 0.0308
# Epoch 5/200
#  28672/134515 [=====>........................] - ETA: 9s - loss: 0.0335 - face_only_output_loss: 0.0505 - audio_boosting_output_loss: 0.0461 - conc_output_loss: 0.0332
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-da35803e4caa> in <module>
#      11                            monitor='val_conc_output_loss')],
#      12              validation_data=({'audio_input': validX, 'face_input': validX_extra},
# ---> 13                {'face_only_output':validy, 'audio_boosting_output':validy, 'conc_output':validy}))
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
def get_valid_mae():
    x = model_combined.predict({'audio_input': validX, 'face_input': validX_extra})[2]
    x = x - validy
    x = np.abs(x)
    return np.mean(x)
get_valid_mae()
# Out:
# 0.030769535073725145

# %%
test_pred = model_combined.predict({'audio_input': testX, 'face_input': testX_extra})[2]

# %%
index_to_print = 637
print_mouths(pred=test_pred[index_to_print], gt=testy[index_to_print])

# %%
with open('test_pred_combined_mae_308', 'wb') as f:
    pickle.dump(scalery.inverse_transform(test_pred).reshape((-1,20,2)), f)
with open('test_gt', 'wb') as f:
    pickle.dump(scalery.inverse_transform(testy).reshape((-1,20,2)), f)

# %% [markdown]
# # This is code for the old models!

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # Face Rotation Model

# %%
def create_face_rotation_model():
    return Sequential([
        Dense(32, input_shape=(96,), name='face_rot_dense_1'),
        Activation('relu', name='face_rot_relu_1'),
        Dropout(0.4, name='face_rot_dropout_1'),
        Dense(5, name='face_rot_dense_2'),
        Dense(40, name='face_rot_output'),
    ])
model_face = create_face_rotation_model()
model_face.compile(optimizer='rmsprop', loss='mae')
plot_model(model_face, to_file='model_face_plot.png', show_shapes=True, show_layer_names=True)
model_face.summary()
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# face_rot_dense_1 (Dense)     (None, 32)                3104
# _________________________________________________________________
# face_rot_relu_1 (Activation) (None, 32)                0
# _________________________________________________________________
# face_rot_dropout_1 (Dropout) (None, 32)                0
# _________________________________________________________________
# face_rot_dense_2 (Dense)     (None, 5)                 165
# _________________________________________________________________
# face_rot_output (Dense)      (None, 40)                240
# =================================================================
# Total params: 3,509
# Trainable params: 3,509
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model_face.fit(trainX_extra,trainy,
            epochs = 20, batch_size = 16,
              verbose = 1, shuffle = True, callbacks = [ModelCheckpoint('checkpoint_face_model.h5')],
                validation_data=(validX_extra, validy))
# Out:
# Train on 20239 samples, validate on 2301 samples
# Epoch 1/20
# 20239/20239 [==============================] - 3s 168us/step - loss: 0.0599 - val_loss: 0.0518
# Epoch 2/20
# 20239/20239 [==============================] - 3s 168us/step - loss: 0.0600 - val_loss: 0.0516
# Epoch 3/20
# 20239/20239 [==============================] - 3s 170us/step - loss: 0.0598 - val_loss: 0.0513
# Epoch 4/20
# 20239/20239 [==============================] - 4s 176us/step - loss: 0.0597 - val_loss: 0.0500
# Epoch 5/20
# 20239/20239 [==============================] - 3s 172us/step - loss: 0.0599 - val_loss: 0.0515
# Epoch 6/20
# 20239/20239 [==============================] - 4s 173us/step - loss: 0.0595 - val_loss: 0.0509
# Epoch 7/20
# 20239/20239 [==============================] - 4s 177us/step - loss: 0.0596 - val_loss: 0.0496
# Epoch 8/20
# 20239/20239 [==============================] - 4s 174us/step - loss: 0.0595 - val_loss: 0.0488
# Epoch 9/20
# 20239/20239 [==============================] - 4s 176us/step - loss: 0.0596 - val_loss: 0.0497
# Epoch 10/20
# 20239/20239 [==============================] - 4s 176us/step - loss: 0.0594 - val_loss: 0.0513
# Epoch 11/20
# 20239/20239 [==============================] - 4s 173us/step - loss: 0.0593 - val_loss: 0.0510
# Epoch 12/20
# 20239/20239 [==============================] - 4s 178us/step - loss: 0.0595 - val_loss: 0.0491
# Epoch 13/20
# 20239/20239 [==============================] - 4s 175us/step - loss: 0.0593 - val_loss: 0.0499
# Epoch 14/20
# 20239/20239 [==============================] - 4s 173us/step - loss: 0.0592 - val_loss: 0.0486
# Epoch 15/20
# 20239/20239 [==============================] - 3s 168us/step - loss: 0.0591 - val_loss: 0.0507
# Epoch 16/20
# 20239/20239 [==============================] - 4s 174us/step - loss: 0.0590 - val_loss: 0.0482
# Epoch 17/20
# 20239/20239 [==============================] - 4s 174us/step - loss: 0.0590 - val_loss: 0.0497
# Epoch 18/20
# 20239/20239 [==============================] - 3s 171us/step - loss: 0.0589 - val_loss: 0.0484
# Epoch 19/20
# 20239/20239 [==============================] - 3s 170us/step - loss: 0.0588 - val_loss: 0.0494
# Epoch 20/20
# 20239/20239 [==============================] - 3s 172us/step - loss: 0.0589 - val_loss: 0.0495

# %%
test_pred = model_face.predict(testX_extra)

# %%
index_to_print = 225
print_mouths(pred=test_pred[index_to_print], gt=testy[index_to_print])

# %% [markdown]
# # Boosting Dataset

# %%
def get_remains(X_extra, y):
    return y - model_face.predict(X_extra)

# %%
trainy_remain = get_remains(trainX_extra, trainy)
validy_remain = get_remains(validX_extra, validy)
testy_remain  = get_remains(testX_extra , testy )

# %% [markdown]
# # Boosting Model

# %%
def create_boosting_model():
    return Sequential([
        TimeDistributed(Dense(100, name='boosting_dense_TD_1'), input_shape=(look_back, 39), name='boosting_TD_1'),
        TimeDistributed(Dense(5, name='boosting_dense_TD_2'), name='boosting_TD_2'),
        Flatten(name='boosting_flatten'),
        Dropout(0.2, name='boosting_dropout_1'),
        Dense(5, name='boosting_dense_1'),
        Activation('sigmoid', name='boosting_activation_1'),
        Dense(40, name='boosting_dense_2')
    ])
model_boost = create_boosting_model()
model_boost.compile(optimizer='adam', loss='mae')
plot_model(model_boost, to_file='model_boost_plot.png', show_shapes=True, show_layer_names=True)
model_boost.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# boosting_TD_1 (TimeDistribut (None, 100, 100)          4000
# _________________________________________________________________
# boosting_TD_2 (TimeDistribut (None, 100, 5)            505
# _________________________________________________________________
# boosting_flatten (Flatten)   (None, 500)               0
# _________________________________________________________________
# boosting_dropout_1 (Dropout) (None, 500)               0
# _________________________________________________________________
# boosting_dense_1 (Dense)     (None, 5)                 2505
# _________________________________________________________________
# boosting_activation_1 (Activ (None, 5)                 0
# _________________________________________________________________
# boosting_dense_2 (Dense)     (None, 40)                240
# =================================================================
# Total params: 7,250
# Trainable params: 7,250
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model_boost.fit(trainX,trainy_remain,
            epochs = 100, batch_size = 32,
              verbose = 1, shuffle = False, callbacks = [ModelCheckpoint('checkpoint_boosting_model.h5')],
                validation_data=(validX, validy_remain))
# Out:
# Train on 20239 samples, validate on 2301 samples
# Epoch 1/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0461 - val_loss: 0.0473
# Epoch 2/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0459 - val_loss: 0.0470
# Epoch 3/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0459 - val_loss: 0.0470
# Epoch 4/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0459 - val_loss: 0.0468
# Epoch 5/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0460 - val_loss: 0.0471
# Epoch 6/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0460 - val_loss: 0.0468
# Epoch 7/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0460 - val_loss: 0.0469
# Epoch 8/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0461 - val_loss: 0.0468
# Epoch 9/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0461 - val_loss: 0.0469
# Epoch 10/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0460 - val_loss: 0.0467
# Epoch 11/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0459 - val_loss: 0.0469
# Epoch 12/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0460 - val_loss: 0.0470
# Epoch 13/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0459 - val_loss: 0.0473
# Epoch 14/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0460 - val_loss: 0.0470
# Epoch 15/100
# 20239/20239 [==============================] - 3s 146us/step - loss: 0.0459 - val_loss: 0.0469
# Epoch 16/100
# 20239/20239 [==============================] - 3s 143us/step - loss: 0.0459 - val_loss: 0.0467
# Epoch 17/100
# 20239/20239 [==============================] - 3s 144us/step - loss: 0.0459 - val_loss: 0.0470
# Epoch 18/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0459 - val_loss: 0.0470
# Epoch 19/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0460 - val_loss: 0.0469
# Epoch 20/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0459 - val_loss: 0.0469
# Epoch 21/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0459 - val_loss: 0.0467
# Epoch 22/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0459 - val_loss: 0.0471
# Epoch 23/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0459 - val_loss: 0.0471
# Epoch 24/100
# 20239/20239 [==============================] - 3s 125us/step - loss: 0.0459 - val_loss: 0.0469
# Epoch 25/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0458 - val_loss: 0.0470
# Epoch 26/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0459 - val_loss: 0.0471
# Epoch 27/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0458 - val_loss: 0.0470
# Epoch 28/100
# 20239/20239 [==============================] - 2s 123us/step - loss: 0.0459 - val_loss: 0.0470
# Epoch 29/100
# 20239/20239 [==============================] - 2s 123us/step - loss: 0.0458 - val_loss: 0.0472
# Epoch 30/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0459 - val_loss: 0.0470
# Epoch 31/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0458 - val_loss: 0.0469
# Epoch 32/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0458 - val_loss: 0.0472
# Epoch 33/100
# 20239/20239 [==============================] - 2s 123us/step - loss: 0.0459 - val_loss: 0.0473
# Epoch 34/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0458 - val_loss: 0.0469
# Epoch 35/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0458 - val_loss: 0.0468
# Epoch 36/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0459 - val_loss: 0.0472
# Epoch 37/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0458 - val_loss: 0.0472
# Epoch 38/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0459 - val_loss: 0.0470
# Epoch 39/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0458 - val_loss: 0.0470
# Epoch 40/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0458 - val_loss: 0.0469
# Epoch 41/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0458 - val_loss: 0.0470
# Epoch 42/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0458 - val_loss: 0.0468
# Epoch 43/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0459 - val_loss: 0.0473
# Epoch 44/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0458 - val_loss: 0.0468
# Epoch 45/100
# 20239/20239 [==============================] - 3s 127us/step - loss: 0.0458 - val_loss: 0.0470
# Epoch 46/100
# 20239/20239 [==============================] - 3s 126us/step - loss: 0.0457 - val_loss: 0.0471
# Epoch 47/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0458 - val_loss: 0.0470
# Epoch 48/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0457 - val_loss: 0.0470
# Epoch 49/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0458 - val_loss: 0.0471
# Epoch 50/100
# 20239/20239 [==============================] - 3s 128us/step - loss: 0.0457 - val_loss: 0.0470
# Epoch 51/100
#  6912/20239 [=========>....................] - ETA: 1s - loss: 0.0451
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-173-14ef3e6ba6e6> in <module>
#       2             epochs = 100, batch_size = 32,
#       3               verbose = 1, shuffle = False, callbacks = [ModelCheckpoint('checkpoint_boosting_model.h5')],
# ----> 4                 validation_data=(validX, validy_remain))
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     183                         # Do not slice the training phase flag.
#     184                         ins_batch = slice_arrays(
# --> 185                             ins[:-1], batch_ids) + [ins[-1]]
#     186                     else:
#     187                         ins_batch = slice_arrays(ins, batch_ids)
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/utils/generic_utils.py in slice_arrays(arrays, start, stop)
#     524             if hasattr(start, 'shape'):
#     525                 start = start.tolist()
# --> 526             return [None if x is None else x[start] for x in arrays]
#     527         else:
#     528             return [None if x is None else x[start:stop] for x in arrays]
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/utils/generic_utils.py in <listcomp>(.0)
#     524             if hasattr(start, 'shape'):
#     525                 start = start.tolist()
# --> 526             return [None if x is None else x[start] for x in arrays]
#     527         else:
#     528             return [None if x is None else x[start:stop] for x in arrays]
#
# KeyboardInterrupt:

# %%
test_pred = model_face.predict(testX_extra) + model_boost.predict(testX)

# %%
index_to_print = 245
print_mouths(pred=test_pred[index_to_print], gt=testy[index_to_print])

# %%
with open('pred_with_boosting', 'wb') as f:
    pickle.dump(scalery.inverse_transform(test_pred).reshape((test_pred.shape[0], -1, 2)), f)

# %%
with open('gt', 'wb') as f:
    pickle.dump(scalery.inverse_transform(testy).reshape((testy.shape[0], -1, 2)), f)

# %% [markdown]
# # Loss

# %%
def mouth_opening_loss(y_true, y_pred):
#     def get_mouth_opening_distances(y):
#         y = y[1::2]
#         return y[13:16] - y[19:16:-1]
    def mse(y_true, y_pred):
        return K.mean(K.square(y_true-y_pred))
    loss_mse = mse(y_true, y_pred)
    loss_custom = mse(y_true[13:20],y_pred[13:20])
    return 40*loss_custom + loss_mse

# %% [markdown]
# # Model

# %%
keras.backend.clear_session()
main_input = Input(shape=(look_back, 39,), dtype='float32', name='main_input')
lstm_out = LSTM(25, input_shape = (look_back, 39))(main_input)
lstm_out_do = Dropout(0.25)(lstm_out)

face_inpput = Input(shape=(48*2,), dtype='float32', name='face_input')
conc_layer = keras.layers.concatenate([lstm_out_do, face_inpput])
dense_layer = Dropout(0.25)(LeakyReLU(alpha=0.05)(Dense(100)(conc_layer)))
dense_layer = Dropout(0.25)(LeakyReLU(alpha=0.05)(Dense(100)(dense_layer)))
dense_layer = Dense(40)(dense_layer)

model = Model(inputs=[main_input, face_inpput], outputs=dense_layer)

# %%
# model.load_weights('checkpoint.h5')
model.compile(optimizer='rmsprop', 
              loss=mouth_opening_loss, 
              metrics=['accuracy'])
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 50, 39)       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 25)           6500        main_input[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 25)           0           lstm_1[0][0]
# __________________________________________________________________________________________________
# face_input (InputLayer)         (None, 96)           0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 121)          0           dropout_1[0][0]
#                                                                  face_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          12200       concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 100)          0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          10100       dropout_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 100)          0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 40)           4040        dropout_3[0][0]
# ==================================================================================================
# Total params: 32,840
# Trainable params: 32,840
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
filepath="checkpoint.h5"

# checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
checkpoint = ModelCheckpoint(filepath)
tbCallback = [checkpoint]

# %%
def mean_to_0(y):
    y[:,::2] -= y[:,::2].mean(axis=1, keepdims=True)
    y[:,1::2] -= y[:,1::2].mean(axis=1, keepdims=True)
    return y

# %%
trainy = mean_to_0(trainy)

# %%
testy = mean_to_0(testy)

# %%
# def run_epoch(trainX, trainX_extra, trainy,
#               valX,   valX_extra,   valy,
#               testX,  testX_extra,  testy, 
#               epochs = 1, batch_size = 1,
#                   verbose = 100, shuffle = True, callbacks = tbCallback):
    
#         model.fit({'main_input':trainX, 'face_input':trainX_extra},trainy,
#                     epochs = epochs, batch_size = batch_size,
#                     verbose = verbose, shuffle = shuffle, callbacks = callbacks, 
#                     validation_data = ({'main_input':valX, 'face_input':valX_extra},valy))
        
#         test_error = np.mean(np.square(testy - model.predict({'main_input':testX, 'face_input':testX_extra})))
#         print('Test Error: ', test_error)

# %%
scalerX = sklearn.preprocessing.MinMaxScaler()
scalerX_extra = sklearn.preprocessing.MinMaxScaler()
scalery = sklearn.preprocessing.MinMaxScaler()

# %%
scalerX.fit(trainX.reshape((trainX.shape[0],-1)))
scalerX_extra.fit(trainX_extra)
scalery.fit(trainy)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
trainX = scalerX.transform(trainX.reshape((-1,50*39))).reshape((-1,50,39))
trainX_extra = scalerX_extra.transform(trainX_extra)
trainy = scalery.transform(trainy)

# %%
testX = scalerX.transform(testX.reshape((testX.shape[0], -1))).reshape((-1,50,39))
testX_extra = scalerX_extra.transform(testX_extra)
testy = scalery.transform(testy)

# %%
trainX.shape
# Out:
# (20239, 50, 39)

# %%
history = model.fit({'main_input':trainX, 'face_input':trainX_extra},trainy,
            epochs = 100, batch_size = 201,
              verbose = 1, shuffle = True, callbacks = tbCallback)
# Out:
# Epoch 1/100
# 20239/20239 [==============================] - 8s 391us/step - loss: 0.2592 - acc: 0.2900
# Epoch 2/100
# 20239/20239 [==============================] - 7s 341us/step - loss: 0.2527 - acc: 0.2916
# Epoch 3/100
# 20239/20239 [==============================] - 7s 346us/step - loss: 0.2354 - acc: 0.2988
# Epoch 4/100
# 20239/20239 [==============================] - 7s 350us/step - loss: 0.2214 - acc: 0.3114
# Epoch 5/100
# 20239/20239 [==============================] - 7s 349us/step - loss: 0.2190 - acc: 0.3195
# Epoch 6/100
# 20239/20239 [==============================] - 7s 351us/step - loss: 0.2160 - acc: 0.3192
# Epoch 7/100
# 20239/20239 [==============================] - 7s 352us/step - loss: 0.2129 - acc: 0.3320
# Epoch 8/100
# 20239/20239 [==============================] - 7s 354us/step - loss: 0.2287 - acc: 0.3277
# Epoch 9/100
#  4221/20239 [=====>........................] - ETA: 5s - loss: 0.1938 - acc: 0.3352
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-251-42039e18fe58> in <module>
#       1 history = model.fit({'main_input':trainX, 'face_input':trainX_extra},trainy,
#       2             epochs = 100, batch_size = 201,
# ----> 3               verbose = 1, shuffle = True, callbacks = tbCallback)
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-32356a16f714> in <module>
#       1 # summarize history for accuracy
# ----> 2 plt.plot(history.history['loss'])
#       3 plt.title('model loss')
#       4 plt.ylabel('loss')
#       5 plt.xlabel('epoch')
#
# NameError: name 'history' is not defined

# %%
test_pred = model.predict({'main_input':testX, 'face_input':testX_extra})

# %%
err = test_pred-testy
err = np.mean(np.square(err), axis=1)

# %%
np.mean(err)
# Out:
# 0.004443956232462654

# %%
min_ind = np.argmax(err)

# %%
print(np.max(err))
# Out:
# 0.0015492171137978076

# %%
with open('testY_pred', 'wb') as f:
    pickle.dump(test_pred, f)

# %%
features_files[140:141]
# Out:
# ['0205.mp4.pickle']

# %%
features_files[140]
# Out:
# '0205.mp4.pickle'

# %%
min_ind = 30
def print_line(points, color='b'):
    points = scalery.inverse_transform([points])[0]
    x = points[::2]
    y = -points[1::2]
    plt.plot(x[:12],y[:12],color)
    plt.plot(x[[0,11]],y[[0,11]],color)
    plt.plot(x[[0,12]],y[[0,12]],color)
    plt.plot(x[[6,16]],y[[6,16]],color)
    plt.plot(x[[19,12]],y[[19,12]],color)
    plt.plot(x[12:20], y[12:20],color)
# print_line(testy[min_ind])
print_line(test_pred[min_ind],'r')
print_line(test_pred[min_ind+1],'r')
print_line(test_pred[min_ind+2],'r')
print_line(test_pred[min_ind+3],'r')
plt.title('blue-GT, red-Pred, Mouth is too open')
# Out:
# Text(0.5, 1.0, 'blue-GT, red-Pred, Mouth is too open')

# %%
with open('train_pred.pickle','wb') as f:
    pickle.dump(train_pred, f)

# %%
with tqdm(list(range(n_epoch))) as tqdm_epochs:
    for i in tqdm_epochs:
        X, X_extra, y = get_random_data(2)
        
        split1 = int(0.8*len(X))
        split2 = int(0.9*len(X))

        trainX = X[0:      split1]
        valX   = X[split1: split2]
        testX  = X[split2:       ]
        
        trainX_extra = X_extra[0:      split1]
        valX_extra   = X_extra[split1: split2]
        testX_extra  = X_extra[split2:       ]
        
        trainy = y[0:      split1]
        valy   = y[split1: split2]
        testy  = y[split2:       ]
        
        run_epoch(trainX, trainX_extra, trainy,
              valX,   valX_extra,   valy,
              testX,  testX_extra,  testy)

# %%
keras.utils.vis_utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
